# %% [markdown]
# <a href="https://colab.research.google.com/github/BilawalBaloch/Open-cv-/blob/main/open_cv_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First Open cv
# **Image**

# %%
import cv2
from google.colab.patches import cv2_imshow # <--- This line is crucial!

img = cv2.imread("/content/image.1.jpeg")
cv2_imshow(img)
cv2.waitKey(1000)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=3000x1583>
